# %%
ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is B806-9082
#
#  Directory of C:\Users\workstation\Desktop\cms-workshop
#
# 07/03/2026  07:48 PM    <DIR>          .
# 07/03/2026  07:48 PM    <DIR>          ..
# 07/03/2026  07:24 PM    <DIR>          .ipynb_checkpoints
# 07/02/2026  10:26 PM    <DIR>          data
# 07/02/2026  09:39 PM             8,347 Lesson1.ipynb
# 07/03/2026  07:48 PM             1,758 Untitled.ipynb
#                2 File(s)         10,105 bytes
#                4 Dir(s)  291,637,047,296 bytes free

# %%
ls data
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is B806-9082
#
#  Directory of C:\Users\workstation\Desktop\cms-workshop\data
#
# 07/02/2026  10:26 PM    <DIR>          .
# 07/02/2026  10:26 PM    <DIR>          ..
# 11/05/2020  10:27 AM           212,934 03_Prod.mdout
# 11/05/2020  10:27 AM               619 benzene.xyz
# 11/05/2020  10:27 AM             2,471 buckminsterfullerene.xyz
# 11/05/2020  10:27 AM           355,359 distance_data_headers.csv
# 07/02/2026  10:26 PM    <DIR>          outfiles
# 11/05/2020  10:27 AM            61,568 sapt.out
# 11/05/2020  10:27 AM               155 water.xyz
#                6 File(s)        633,106 bytes
#                3 Dir(s)  291,636,121,600 bytes free

# %%
pwd
# Out:
# 'C:\\Users\\workstation\\Desktop\\cms-workshop'

# %%
import os

# %%
ethanol_file = os.path.join("data", "outfiles", "ethanol.out")

# %%
print(ethanol_file)
# Out:
# data\outfiles\ethanol.out

# %%
print(os.path.abspath(ethanol_file))
# Out:
# C:\Users\workstation\Desktop\cms-workshop\data\outfiles\ethanol.out

# %%
outfile = open(ethanol_file, "r")

# %%
data = outfile.readlines()

# %%
len(data)
# Out:
# 270

# %%
print(data[0])

# %%
print(data[1])
# Out:
#     -----------------------------------------------------------------------

# %%
print(data[:5])
# Out:
# ['\n', '    -----------------------------------------------------------------------\n', '          Psi4: An Open-Source Ab Initio Electronic Structure Package\n', '                               Psi4 1.1 release\n', '\n']

# %%
outfile.close()

# %%
with open(ethanol_file, "r") as outfile:
    data = outfile.readlines()

# %%
for line in data:
    print(line)
# Out:
#     -----------------------------------------------------------------------
#
#           Psi4: An Open-Source Ab Initio Electronic Structure Package
#
#                                Psi4 1.1 release
#
#
#
#                          Git: Rev {HEAD} add49b9
#
#
#
#
#
#     R. M. Parrish, L. A. Burns, D. G. A. Smith, A. C. Simmonett,
#
#     A. E. DePrince III, E. G. Hohenstein, U. Bozkaya, A. Yu. Sokolov,
#
#     R. Di Remigio, R. M. Richard, J. F. Gonthier, A. M. James,
#
#     H. R. McAlexander, A. Kumar, M. Saitow, X. Wang, B. P. Pritchard,
#
#     P. Verma, H. F. Schaefer III, K. Patkowski, R. A. King, E. F. Valeev,
#
#     F. A. Evangelista, J. M. Turney, T. D. Crawford, and C. D. Sherrill,
#
#     J. Chem. Theory Comput. in press (2017).
#
#     (doi: 10.1021/acs.jctc.7b00174)
#
#
#
#     -----------------------------------------------------------------------
#
#
#
#
#
#     Psi4 started on: Tuesday, 27 June 2017 12:10PM
#
#
#
#     Process ID:  10591
#
# ...

# %%
for line in data:
    if "Final Energy" in line:
        print(line)
# Out:
#   @DF-RHF Final Energy:  -154.09130176573018

# %%
for line in data:
    if "Final Energy" in line:
        energy_line = line

print(energy_line)
# Out:
#   @DF-RHF Final Energy:  -154.09130176573018

# %%
energy_line.split()
# Out:
# ['@DF-RHF', 'Final', 'Energy:', '-154.09130176573018']

# %%
energy_line.split(":")
# Out:
# ['  @DF-RHF Final Energy', '  -154.09130176573018\n']

# %%
words = energy_line.split()

# %%
print(words)
# Out:
# ['@DF-RHF', 'Final', 'Energy:', '-154.09130176573018']

# %%
energy = words[3]

# %%
print(energy)
# Out:
# -154.09130176573018

# %%
type(energy)
# Out:
# str

# %%
energy = words[-1]

print(energy)
# Out:
# -154.09130176573018

# %%
print(type(energy))
# Out:
# <class 'str'>

# %%
energy = float(energy)

print(type(energy))
# Out:
# <class 'float'>

# %%
print(energy + 50)
# Out:
# -104.09130176573018

# %%
with open('data/sapt.out', 'r') as file:
    data = file.readlines()

# %%
len(data)
# Out:
# 1535

# %%
print(data[0])

# %%
print(data[:10])
# Out:
# ['\n', '    -----------------------------------------------------------------------\n', '          Psi4: An Open-Source Ab Initio Electronic Structure Package\n', '                               Psi4 1.2.1 release\n', '\n', '                         Git: Rev {HEAD} 406f4de \n', '\n', '\n', '    R. M. Parrish, L. A. Burns, D. G. A. Smith, A. C. Simmonett,\n', '    A. E. DePrince III, E. G. Hohenstein, U. Bozkaya, A. Yu. Sokolov,\n']

# %%
important_lines = []

# %%
with open('data/sapt.out', 'r') as saptout:
    for line in saptout:
        if 'Electrostatics' in line:
            important_lines.append(line)

# %%
len(important_lines)
# Out:
# 2

# %%
print(important_lines)
# Out:
# ['    Electrostatics                 -3.59915058 [mEh]      -2.25850118 [kcal/mol]      -9.44956984 [kJ/mol]\n', '    Electrostatics sSAPT0          -3.59915058 [mEh]      -2.25850118 [kcal/mol]      -9.44956984 [kJ/mol]\n']

# %%
for line in important_lines:
    words = line.split()
    print(words)
# Out:
# ['Electrostatics', '-3.59915058', '[mEh]', '-2.25850118', '[kcal/mol]', '-9.44956984', '[kJ/mol]']
# ['Electrostatics', 'sSAPT0', '-3.59915058', '[mEh]', '-2.25850118', '[kcal/mol]', '-9.44956984', '[kJ/mol]']

# %%
words = important_lines[0].split()

print(words)
# Out:
# ['Electrostatics', '-3.59915058', '[mEh]', '-2.25850118', '[kcal/mol]', '-9.44956984', '[kJ/mol]']

# %%
energy = float(words[3])

print(energy)
# Out:
# -2.25850118

# %%
energy_types = [
    'Electrostatics',
    'Exchange',
    'Induction',
    'Dispersion'
]

# %%
print(energy_types)
# Out:
# ['Electrostatics', 'Exchange', 'Induction', 'Dispersion']

# %%
for energy in energy_types:
    print(energy)
# Out:
# Electrostatics
# Exchange
# Induction
# Dispersion

# %%
for energy in energy_types:
    print("Searching for:", energy)

    for line in data:
        if energy in line:
            print(line)
# Out:
# Searching for: Electrostatics
#     Electrostatics                 -3.59915058 [mEh]      -2.25850118 [kcal/mol]      -9.44956984 [kJ/mol]
#
#     Electrostatics sSAPT0          -3.59915058 [mEh]      -2.25850118 [kcal/mol]      -9.44956984 [kJ/mol]
#
# Searching for: Exchange
#     Exchange                        3.62911156 [mEh]       2.27730198 [kcal/mol]       9.52823241 [kJ/mol]
#
#     Exchange sSAPT0                 3.62911156 [mEh]       2.27730198 [kcal/mol]       9.52823241 [kJ/mol]
#
# Searching for: Induction
#     Induction                      -0.83137115 [mEh]      -0.52169330 [kcal/mol]      -2.18276496 [kJ/mol]
#
#     Induction sSAPT0               -0.82185559 [mEh]      -0.51572219 [kcal/mol]      -2.15778186 [kJ/mol]
#
# Searching for: Dispersion
#     Dispersion                     -1.50542374 [mEh]      -0.94466770 [kcal/mol]      -3.95249003 [kJ/mol]
#
#     Dispersion sSAPT0              -1.50279823 [mEh]      -0.94302016 [kcal/mol]      -3.94559675 [kJ/mol]

# %%
for linenum, line in enumerate(data):
    print(linenum, line)
# Out:
# 0
#
# 1     -----------------------------------------------------------------------
#
# 2           Psi4: An Open-Source Ab Initio Electronic Structure Package
#
# 3                                Psi4 1.2.1 release
#
# 4
#
# 5                          Git: Rev {HEAD} 406f4de
#
# 6
#
# 7
#
# 8     R. M. Parrish, L. A. Burns, D. G. A. Smith, A. C. Simmonett,
#
# 9     A. E. DePrince III, E. G. Hohenstein, U. Bozkaya, A. Yu. Sokolov,
#
# 10     R. Di Remigio, R. M. Richard, J. F. Gonthier, A. M. James,
#
# 11     H. R. McAlexander, A. Kumar, M. Saitow, X. Wang, B. P. Pritchard,
#
# 12     P. Verma, H. F. Schaefer III, K. Patkowski, R. A. King, E. F. Valeev,
#
# 13     F. A. Evangelista, J. M. Turney, T. D. Crawford, and C. D. Sherrill,
#
# 14     J. Chem. Theory Comput. 13(7) pp 3185--3197 (2017).
#
# 15     (doi: 10.1021/acs.jctc.7b00174)
#
# 16
#
# 17
#
# 18                          Additional Contributions by
#
# ...

# %%
for linenum, line in enumerate(data):
    if "Center" in line:
        print(linenum)
        print(line)
# Out:
# 109
#        Center              X                  Y                   Z               Mass
#
# 220
#        Center              X                  Y                   Z               Mass
#
# 239
#        Center              X                  Y                   Z               Mass
#
# 282
#        Center              X                  Y                   Z               Mass
#
# 301
#        Center              X                  Y                   Z               Mass
#
# 478
#        Center              X                  Y                   Z               Mass
#
# 589
#        Center              X                  Y                   Z               Mass
#
# 608
#        Center              X                  Y                   Z               Mass
#
# 651
#        Center              X                  Y                   Z               Mass
#
# 670
#        Center              X                  Y                   Z               Mass
#
# 709
# ...

# %%
for linenum, line in enumerate(data):
    if "Center" in line:
        print(linenum)
        print(line)
        break
# Out:
# 109
#        Center              X                  Y                   Z               Mass

# %%
for line in data[109:115]:
    print(line)
# Out:
#        Center              X                  Y                   Z               Mass
#
#     ------------   -----------------  -----------------  -----------------  -----------------
#
#          C            0.000000000000    -0.667578000000    -2.128156293689    12.000000000000
#
#          C            0.000000000000     0.667578000000    -2.128156293689    12.000000000000
#
#          H            0.923621000000    -1.232253000000    -2.129682293689     1.007825032070
#
#          H           -0.923621000000    -1.232253000000    -2.129682293689     1.007825032070

# %%
coordinates = data[111:120]

for line in coordinates:
    print(line)
# Out:
#          C            0.000000000000    -0.667578000000    -2.128156293689    12.000000000000
#
#          C            0.000000000000     0.667578000000    -2.128156293689    12.000000000000
#
#          H            0.923621000000    -1.232253000000    -2.129682293689     1.007825032070
#
#          H           -0.923621000000    -1.232253000000    -2.129682293689     1.007825032070
#
#          H           -0.923621000000     1.232253000000    -2.129682293689     1.007825032070
#
#          H            0.923621000000     1.232253000000    -2.129682293689     1.007825032070
#
#          C            0.000000000000     0.000000000000     2.897005706311    12.000000000000
#
#          C            0.000000000000     0.000000000000     1.689742706311    12.000000000000
#
#          H            0.000000000000     0.000000000000     0.623854706311     1.007825032070

# %%
len(coordinates)
# Out:
# 9
